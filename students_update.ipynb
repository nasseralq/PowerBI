# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('student_data.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df['school'] = df['school'].replace(['GP','MS'],['Gabriel Pereira','Mousinho da Silveira'])

# %%
 df.rename(columns = {'sex':'gender'}, inplace = True)

# %%
df
# Out:
#                    school gender  age address famsize Pstatus  Medu  Fedu  \
# 0         Gabriel Pereira      F   18       U     GT3       A     4     4
# 1         Gabriel Pereira      F   17       U     GT3       T     1     1
# 2         Gabriel Pereira      F   15       U     LE3       T     1     1
# 3         Gabriel Pereira      F   15       U     GT3       T     4     2
# 4         Gabriel Pereira      F   16       U     GT3       T     3     3
# ..                    ...    ...  ...     ...     ...     ...   ...   ...
# 390  Mousinho da Silveira      M   20       U     LE3       A     2     2
# 391  Mousinho da Silveira      M   17       U     LE3       T     3     1
# 392  Mousinho da Silveira      M   21       R     GT3       T     1     1
# 393  Mousinho da Silveira      M   18       R     LE3       T     3     2
# 394  Mousinho da Silveira      M   19       U     LE3       T     1     1
#
#          Mjob      Fjob  ... famrel freetime  goout  Dalc  Walc health  \
# ...

# %%
df['gender'] = df['gender'].replace(['M','F'],['Male','Famle'])

# %%
df
# Out:
#                    school gender  age address famsize Pstatus  Medu  Fedu  \
# 0         Gabriel Pereira  Famle   18       U     GT3       A     4     4
# 1         Gabriel Pereira  Famle   17       U     GT3       T     1     1
# 2         Gabriel Pereira  Famle   15       U     LE3       T     1     1
# 3         Gabriel Pereira  Famle   15       U     GT3       T     4     2
# 4         Gabriel Pereira  Famle   16       U     GT3       T     3     3
# ..                    ...    ...  ...     ...     ...     ...   ...   ...
# 390  Mousinho da Silveira   Male   20       U     LE3       A     2     2
# 391  Mousinho da Silveira   Male   17       U     LE3       T     3     1
# 392  Mousinho da Silveira   Male   21       R     GT3       T     1     1
# 393  Mousinho da Silveira   Male   18       R     LE3       T     3     2
# 394  Mousinho da Silveira   Male   19       U     LE3       T     1     1
#
#          Mjob      Fjob  ... famrel freetime  goout  Dalc  Walc health  \
# ...

# %%
df['address'] = df['address'].replace(['U','R'],['Urban','Rural'])

# %%
df
# Out:
#                    school gender  age address famsize Pstatus  Medu  Fedu  \
# 0         Gabriel Pereira  Famle   18   Urban     GT3       A     4     4
# 1         Gabriel Pereira  Famle   17   Urban     GT3       T     1     1
# 2         Gabriel Pereira  Famle   15   Urban     LE3       T     1     1
# 3         Gabriel Pereira  Famle   15   Urban     GT3       T     4     2
# 4         Gabriel Pereira  Famle   16   Urban     GT3       T     3     3
# ..                    ...    ...  ...     ...     ...     ...   ...   ...
# 390  Mousinho da Silveira   Male   20   Urban     LE3       A     2     2
# 391  Mousinho da Silveira   Male   17   Urban     LE3       T     3     1
# 392  Mousinho da Silveira   Male   21   Rural     GT3       T     1     1
# 393  Mousinho da Silveira   Male   18   Rural     LE3       T     3     2
# 394  Mousinho da Silveira   Male   19   Urban     LE3       T     1     1
#
#          Mjob      Fjob  ... famrel freetime  goout  Dalc  Walc health  \
# ...

# %%
df.columns
# Out:
# Index(['school', 'gender', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.columns = ['School', 'Gender', 'Age', 'Address','Family_size','parents_status',
              'Mother_edu','Father_edu', 'Mother_job', 'Father_job', 'Reason', 'Guardian',
              'Travel_time', 'Study_time','Failures', 'School_support', 'Family_support', 'Paid', 'Activities', 'Nursery',
       'Higher_edu', 'Internet_at_home', 'Romantic_relationship', 'Family_relationship', 'Free_time', 'Go_out', 'Daily_alcohol',
       'Weekend_alcohol', 'Health', 'Absences', 'First_period_grade', 'Second_period_grade', 'Final_grade']

# %%
df
# Out:
#                    School Gender  Age Address Family_size parents_status  \
# 0         Gabriel Pereira  Famle   18   Urban         GT3              A
# 1         Gabriel Pereira  Famle   17   Urban         GT3              T
# 2         Gabriel Pereira  Famle   15   Urban         LE3              T
# 3         Gabriel Pereira  Famle   15   Urban         GT3              T
# 4         Gabriel Pereira  Famle   16   Urban         GT3              T
# ..                    ...    ...  ...     ...         ...            ...
# 390  Mousinho da Silveira   Male   20   Urban         LE3              A
# 391  Mousinho da Silveira   Male   17   Urban         LE3              T
# 392  Mousinho da Silveira   Male   21   Rural         GT3              T
# 393  Mousinho da Silveira   Male   18   Rural         LE3              T
# 394  Mousinho da Silveira   Male   19   Urban         LE3              T
#
#      Mother_edu  Father_edu Mother_job Father_job  ... Family_relationship  \
# ...

# %%
df['Family_size'] = df['Family_size'].replace(['GT3','LE3'],['Greater than 3','3 or less'])

# %%
df.columns
# Out:
# Index(['School', 'Gender', 'Age', 'Address', 'Family_size', 'parents_status',
#        'Mother_edu', 'Father_edu', 'Mother_job', 'Father_job', 'Reason',
#        'Guardian', 'Travel_time', 'Study_time', 'Failures', 'School_support',
#        'Family_support', 'Paid', 'Activities', 'Nursery', 'Higher_edu',
#        'Internet_at_home', 'Romantic_relationship', 'Family_relationship',
#        'Free_time', 'Go_out', 'Daily_alcohol', 'Weekend_alcohol', 'Health',
#        'Absences', 'First_period_grade', 'Second_period_grade', 'Final_grade'],
#       dtype='object')

# %%
df
# Out:
#                    School Gender  Age Address     Family_size parents_status  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3              A
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3              T
# 2         Gabriel Pereira  Famle   15   Urban       3 or less              T
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3              T
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3              T
# ..                    ...    ...  ...     ...             ...            ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less              A
# 391  Mousinho da Silveira   Male   17   Urban       3 or less              T
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3              T
# 393  Mousinho da Silveira   Male   18   Rural       3 or less              T
# 394  Mousinho da Silveira   Male   19   Urban       3 or less              T
#
# ...

# %%
df['parents_status'] = df['parents_status'].replace(['T','A'],['Living together','Apart'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status  Mother_edu  Father_edu Mother_job Father_job  ...  \
# 0              Apart           4           4    at_home    teacher  ...
# 1    Living together           1           1    at_home      other  ...
# ...

# %%
df['Mother_edu'] = df['Mother_edu'].replace([0,1,2,3,4],['None','Primary education',' 5th to 9th grade',' Secondary education','Higher education'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu  Father_edu Mother_job Father_job  \
# 0              Apart      Higher education           4    at_home    teacher
# ...

# %%
df['Father_edu'] = df['Father_edu'].replace([0,1,2,3,4],['None','Primary education',' 5th to 9th grade',' Secondary education','Higher education'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df.Travel_time.sample
# Out:
# <bound method NDFrame.sample of 0      2
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 390    1
# 391    2
# 392    1
# 393    3
# 394    1
# Name: Travel_time, Length: 395, dtype: int64>

# %%
df['Travel_time'] = df['Travel_time'].replace([1,2,3,4],['<15 min','15 to 30 min',' 30 min. to 1 hour','>1 hour'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Study_time'] = df['Study_time'].replace([1,2,3,4],['<2 hours','2 to 5 hours','5 to 10 hours','>10 hours'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
Fail= df.Failures.value_counts()
Fail
# Out:
# 0    312
# 1     50
# 2     17
# 3     16
# Name: Failures, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#             School Gender  Age Address     Family_size   parents_status  \
# 0  Gabriel Pereira  Famle   18   Urban  Greater than 3            Apart
# 1  Gabriel Pereira  Famle   17   Urban  Greater than 3  Living together
# 2  Gabriel Pereira  Famle   15   Urban       3 or less  Living together
# 3  Gabriel Pereira  Famle   15   Urban  Greater than 3  Living together
# 4  Gabriel Pereira  Famle   16   Urban  Greater than 3  Living together
#
#              Mother_edu            Father_edu Mother_job Father_job  Reason  \
# 0      Higher education      Higher education    at_home    teacher  course
# 1     Primary education     Primary education    at_home      other  course
# 2     Primary education     Primary education    at_home      other   other
# 3      Higher education      5th to 9th grade     health   services    home
# 4   Secondary education   Secondary education      other      other    home
#
#   Guardian   Travel_time     Study_time  Failures School_support  \
# ...

# %%
df['Family_relationship'] = df['Family_relationship'].replace([1,2,3,4,5],['Very bad','Bad','Normal','Good','Excellent'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Free_time'] = df['Free_time'].replace([1,2,3,4,5],['Very low','Low','Medium','High','Very high'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Go_out'] = df['Go_out'].replace([1,2,3,4,5],['Very low','Low','Medium','High','Very high'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Daily_alcohol'] = df['Daily_alcohol'].replace([1,2,3,4,5],['Very low','Low','Medium','High','Very high'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Weekend_alcohol'] = df['Weekend_alcohol'].replace([1,2,3,4,5],['Very low','Low','Medium','High','Very high'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Health'] = df['Health'].replace([1,2,3,4,5],['Very bad','Bad','Fair','Good','Very good'])
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df.First_period_grade
# Out:
# 0       5
# 1       5
# 2       7
# 3      15
# 4       6
#        ..
# 390     9
# 391    14
# 392    10
# 393    11
# 394     8
# Name: First_period_grade, Length: 395, dtype: int64

# %%
type(df['First_period_grade'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   School                 395 non-null    object
#  1   Gender                 395 non-null    object
#  2   Age                    395 non-null    int64
#  3   Address                395 non-null    object
#  4   Family_size            395 non-null    object
#  5   parents_status         395 non-null    object
#  6   Mother_edu             395 non-null    object
#  7   Father_edu             395 non-null    object
#  8   Mother_job             395 non-null    object
#  9   Father_job             395 non-null    object
#  10  Reason                 395 non-null    object
#  11  Guardian               395 non-null    object
#  12  Travel_time            395 non-null    object
#  13  Study_time             395 non-null    object
# ...

# %%
df['First_period_grade'].astype(str)
# Out:
# 0       5
# 1       5
# 2       7
# 3      15
# 4       6
#        ..
# 390     9
# 391    14
# 392    10
# 393    11
# 394     8
# Name: First_period_grade, Length: 395, dtype: object

# %%
def first(First_period_grade):
    if First_period_grade >= 18:
        return "A+"
    elif First_period_grade >=16:
        return "A"
    elif First_period_grade>= 14:
        return "B"
    elif First_period_grade >= 10:
        return "C"
    else:
        return "F"

# %%
df['First_period_grade']= df.First_period_grade.apply(first)
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Second_period_grade']= df.Second_period_grade.apply(first)
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df['Final_grade']= df.Final_grade.apply(first)
df
# Out:
#                    School Gender  Age Address     Family_size  \
# 0         Gabriel Pereira  Famle   18   Urban  Greater than 3
# 1         Gabriel Pereira  Famle   17   Urban  Greater than 3
# 2         Gabriel Pereira  Famle   15   Urban       3 or less
# 3         Gabriel Pereira  Famle   15   Urban  Greater than 3
# 4         Gabriel Pereira  Famle   16   Urban  Greater than 3
# ..                    ...    ...  ...     ...             ...
# 390  Mousinho da Silveira   Male   20   Urban       3 or less
# 391  Mousinho da Silveira   Male   17   Urban       3 or less
# 392  Mousinho da Silveira   Male   21   Rural  Greater than 3
# 393  Mousinho da Silveira   Male   18   Rural       3 or less
# 394  Mousinho da Silveira   Male   19   Urban       3 or less
#
#       parents_status            Mother_edu            Father_edu Mother_job  \
# 0              Apart      Higher education      Higher education    at_home
# ...

# %%
df.to_csv('Students_performance.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   School                 395 non-null    object
#  1   Gender                 395 non-null    object
#  2   Age                    395 non-null    int64
#  3   Address                395 non-null    object
#  4   Family_size            395 non-null    object
#  5   parents_status         395 non-null    object
#  6   Mother_edu             395 non-null    object
#  7   Father_edu             395 non-null    object
#  8   Mother_job             395 non-null    object
#  9   Father_job             395 non-null    object
#  10  Reason                 395 non-null    object
#  11  Guardian               395 non-null    object
#  12  Travel_time            395 non-null    object
#  13  Study_time             395 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age    Failures    Absences
# count  395.000000  395.000000  395.000000
# mean    16.696203    0.334177    5.708861
# std      1.276043    0.743651    8.003096
# min     15.000000    0.000000    0.000000
# 25%     16.000000    0.000000    0.000000
# 50%     17.000000    0.000000    4.000000
# 75%     18.000000    0.000000    8.000000
# max     22.000000    3.000000   75.000000

# %%
df[]
# Out:
#   File "<ipython-input-41-71f11347ebfc>", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax
